# %%
import pandas as pd
import sqlite3
import re
import unicodedata
from io import StringIO

# %%
# TO THE ORIGINAL CSV DATASET I ADDED A NEW COLUMN CALLED -COUNTRY- AND EXTRACT THE COUNTRY NAME
# WITH THE FOLLOWING FORMULA: =TRIM(RIGHT(SUBSTITUTE(cell, ",", REPT(" ", LEN(cell))), LEN(cell)))
# being (cell) the first row with information and replicating the rest

# %%
df = pd.read_csv('space_missions_modified.csv', encoding = 'latin1')

# %%
df_no_duplicates = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4630 entries, 0 to 4629
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        4630 non-null   object
#  1   Location       4630 non-null   object
#  2   Country        4630 non-null   object
#  3   Date           4630 non-null   object
#  4   Time           4503 non-null   object
#  5   Rocket         4630 non-null   object
#  6   Mission        4630 non-null   object
#  7   RocketStatus   4630 non-null   object
#  8   Price          1265 non-null   object
#  9   MissionStatus  4630 non-null   object
# dtypes: object(10)
# memory usage: 361.8+ KB

# %%
df.describe()
# Out:
#           Company                                    Location Country  \
# count        4630                                        4630    4630
# unique         62                                         158      22
# top     RVSN USSR  Site 31/6, Baikonur Cosmodrome, Kazakhstan     USA
# freq         1777                                         251    1467
#
#               Date      Time              Rocket Mission RocketStatus Price  \
# count         4630      4503                4630    4630         4630  1265
# unique        4180      1300                 370    4556            2    65
# top     26/04/1962  12:00:00  Cosmos-3M (11K65M)     DSP      Retired   450
# freq             4        52                 446       8         3620   136
#
#        MissionStatus
# count           4630
# unique             4
# top          Success
# freq            4162

# %%
# Normalizing Time & Price columns
df['Time'] = df['Time'].fillna('None', inplace=False)
df['Price'] = df['Price'].fillna('None', inplace=False)

# %%
# passing dataframe to csv (without index)
df.to_csv('space_missions_normalized.csv', index=False)
# AL ARCHIVO CSV LE AÑADÍ UNA COLUMNA LLAMADA COUNTRY Y LE RECORTÉ A LOCATION EL PAÍS CON LA SIGUIENTE FORMULA:
#

# %%
# Table format sneak peak
df = pd.read_csv('space_missions_normalized.csv')
df.head()
# Out:
#      Company                                   Location     Country  \
# 0  RVSN USSR  Site 1/5, Baikonur Cosmodrome, Kazakhstan  Kazakhstan
# 1  RVSN USSR  Site 1/5, Baikonur Cosmodrome, Kazakhstan  Kazakhstan
# 2    US Navy   LC-18A, Cape Canaveral AFS, Florida, USA         USA
# 3       AMBA   LC-26A, Cape Canaveral AFS, Florida, USA         USA
# 4    US Navy   LC-18A, Cape Canaveral AFS, Florida, USA         USA
#
#          Date      Time          Rocket         Mission RocketStatus Price  \
# 0  04/10/1957  19:28:00  Sputnik 8K71PS       Sputnik-1      Retired   NaN
# 1  03/11/1957  02:30:00  Sputnik 8K71PS       Sputnik-2      Retired   NaN
# 2  06/12/1957  16:44:00        Vanguard    Vanguard TV3      Retired   NaN
# 3  01/02/1958  03:48:00          Juno I      Explorer 1      Retired   NaN
# 4  05/02/1958  07:33:00        Vanguard  Vanguard TV3BU      Retired   NaN
#
#   MissionStatus
# 0       Success
# 1       Success
# 2       Failure
# 3       Success
# 4       Failure
