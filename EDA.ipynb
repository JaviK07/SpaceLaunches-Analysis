# %%
import pandas as pd
import sqlite3
import re
import unicodedata
from io import StringIO

# %%
df = pd.read_csv('space_missions.csv', encoding = 'latin1')

# %%
df_no_duplicates = df.drop_duplicates()

# %%
df
# Out:
#         Company                                         Location        Date  \
# 0     RVSN USSR        Site 1/5, Baikonur Cosmodrome, Kazakhstan  04/10/1957
# 1     RVSN USSR        Site 1/5, Baikonur Cosmodrome, Kazakhstan  03/11/1957
# 2       US Navy         LC-18A, Cape Canaveral AFS, Florida, USA  06/12/1957
# 3          AMBA         LC-26A, Cape Canaveral AFS, Florida, USA  01/02/1958
# 4       US Navy         LC-18A, Cape Canaveral AFS, Florida, USA  05/02/1958
# ...         ...                                              ...         ...
# 4625     SpaceX          SLC-4E, Vandenberg SFB, California, USA  22/07/2022
# 4626       CASC  LC-101, Wenchang Satellite Launch Center, China  24/07/2022
# 4627     SpaceX       LC-39A, Kennedy Space Center, Florida, USA  24/07/2022
# 4628  CAS Space           Jiuquan Satellite Launch Center, China  27/07/2022
# 4629       CASC     LC-3, Xichang Satellite Launch Center, China  29/07/2022
#
#           Time            Rocket              Mission RocketStatus  Price  \
# 0     19:28:00    Sputnik 8K71PS            Sputnik-1      Retired    NaN
# 1     02:30:00    Sputnik 8K71PS            Sputnik-2      Retired    NaN
# 2     16:44:00          Vanguard         Vanguard TV3      Retired    NaN
# 3     03:48:00            Juno I           Explorer 1      Retired    NaN
# 4     07:33:00          Vanguard       Vanguard TV3BU      Retired    NaN
# ...        ...               ...                  ...          ...    ...
# 4625  17:39:00  Falcon 9 Block 5   Starlink Group 3-2       Active     67
# 4626  06:22:00     Long March 5B              Wentian       Active    NaN
# 4627  13:38:00  Falcon 9 Block 5  Starlink Group 4-25       Active     67
# 4628  04:12:00        Zhongke-1A          Demo Flight       Active    NaN
# 4629  13:28:00     Long March 2D   Yaogan 35 Group 03       Active  29.75
#
#      MissionStatus
# 0          Success
# 1          Success
# 2          Failure
# 3          Success
# 4          Failure
# ...            ...
# 4625       Success
# 4626       Success
# 4627       Success
# 4628       Success
# 4629       Success
#
# [4630 rows x 9 columns]

# %%
df.describe()
# Out:
#           Company                                    Location        Date  \
# count        4630                                        4630        4630
# unique         62                                         158        4180
# top     RVSN USSR  Site 31/6, Baikonur Cosmodrome, Kazakhstan  26/04/1962
# freq         1777                                         251           4
#
#             Time              Rocket Mission RocketStatus Price MissionStatus
# count       4503                4630    4630         4630  1265          4630
# unique      1300                 370    4556            2    65             4
# top     12:00:00  Cosmos-3M (11K65M)     DSP      Retired   450       Success
# freq          52                 446       8         3620   136          4162
